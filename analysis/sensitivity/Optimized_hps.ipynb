# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_hdf('../../experiments/new_ts_hpsample.h5')

top = df.loc[:, ['distances__scheme', 'tica__dim', 'tica__lag', 'cluster__k', 'distances__steepness', 'distances__centre']].drop_duplicates()

top.head(5)
# Out:
#       distances__scheme  tica__dim  tica__lag  cluster__k  \
# hp_ix
# 329                  ca         20         90         499
# 330                  ca         20         37         499
# 331                  ca         20         90         489
# 334                  ca         20         55         499
# 335                  ca         20         37         489
#
#        distances__steepness  distances__centre
# hp_ix
# 329                5.967568           0.700806
# 330                5.967568           0.700806
# 331                5.967568           0.700806
# 334                5.967568           0.700806
# 335                5.967568           0.700806

# %%
df2 = pd.read_hdf('../../experiments/new_ts_hpsample_missing_best.h5')
df2.index = np.array(df2.hp_ix) + 11
df2.index.name = 'hp_ix'
top2 = df2.loc[:, ['distances__scheme', 'tica__dim', 'tica__lag', 'cluster__k', 'distances__steepness', 'distances__centre']].drop_duplicates()

top2.head(5)
# Out:
#       distances__scheme  tica__dim  tica__lag  cluster__k  \
# hp_ix
# 340                  ca         15         94         499
# 341                  ca         15         94         499
# 342                  ca         18         94         499
# 343                  ca         15         20         499
# 344                  ca         18         94         499
#
#        distances__steepness  distances__centre
# hp_ix
# 340                5.967568           0.799794
# 341                5.967568           0.769969
# 342                5.967568           0.799794
# 343                5.967568           0.799794
# 344                5.967568           0.769969

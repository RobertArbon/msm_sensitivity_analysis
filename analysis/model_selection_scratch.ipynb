# %%
import h5py 
import pandas as pd
import matplotlib.pyplot as plt
from sensetools.plots import vamps_and_features

# %%
summary = '../data/msms/1fme/summary.h5'
hp_definitions = '../data/msms/hpsample.h5'

with h5py.File(summary, 'r') as f:
    grp = f['summary']
    lag = int(grp.attrs['chosen_lag'])
    k = int(grp.attrs['chosen_k'])
    name = grp.attrs['protein_name']

# %%
vamps = vamps_and_features(summary, hp_definitions)
vamps.reset_index(level=['lag'], inplace=True)
vamps = vamps.loc[vamps.lag == lag, :]
vamps = vamps.drop(labels=['lag'], axis=1)

# %%
gaps = pd.DataFrame(pd.read_hdf(summary, key='timescale_ratio'))
gaps.reset_index(level=['lag'], inplace=True)
gaps = gaps.loc[gaps.lag == lag, :]
gaps = gaps.drop(labels=['lag'], axis=1)
gaps.dropna(inplace=True)

suffixes = ['_vamp', '_gap']
vamps = vamps.merge(gaps, left_index=True, right_index=True, how='inner', suffixes=suffixes)
vamps.reset_index(inplace=True)

# %%
def show_top(df, cutoff=0.03):
    # # Only keep top vamp scores per process
    # df['rank_vamp_per_proc'] = df.groupby(['process'], as_index=False)['median_vamp'].rank(ascending=False)
    # top = df.loc[df['rank_vamp_per_proc']<=cutoff,:].copy()
    keep_ix = 1 - df['median_vamp']/df['process'] < cutoff
    top = df.loc[keep_ix, :].copy()
    
    # of these rank the gaps
    top['rank_gap_per_feature'] = top.groupby(['feature'])['median_gap'].rank(ascending=False)
    
    return top.loc[top['rank_gap_per_feature']==1, :]

# %%
show_top(vamps, cutoff=0.02)
# Out:
#      hp_ix  process  median_vamp   lb_vamp   ub_vamp  count_vamp  \
# 386     86        2     1.961894  1.953491  1.968646         100
# 532     60        2     1.963484  1.957050  1.969161         100
# 677     81        2     1.960240  1.951286  1.966929         100
#
#           feature  median_gap    lb_gap     ub_gap  count_gap  \
# 386  logit(dist.)   11.807128  9.849849  15.667964        100
# 532         dist.    2.340882  1.156287   5.238080        100
# 677        dihed.   11.900826  9.905592  15.723409        100
#
#      rank_gap_per_feature
# 386                   1.0
# 532                   1.0
# 677                   1.0

# %%
vamps['vamp_rank_per_feature'] = vamps.groupby(['process','feature'], as_index=False)['median_vamp'].rank(ascending=False)
vamps.sort_values(by=['process', 'vamp_rank_per_feature'])
# Out:
#       hp_ix  process  median_vamp    lb_vamp    ub_vamp  count_vamp  \
# 274      53        2     1.970976   1.962065   1.986006         100
# 532      60        2     1.963484   1.957050   1.969161         100
# 1290     52        2     1.967703   1.961617   1.973702         100
# 951      33        2     1.967338   1.958334   1.980434         100
# 1252      8        2     1.963457   1.958161   1.972797         100
# ...     ...      ...          ...        ...        ...         ...
# 721      40       20    12.414276  11.471247  13.265532         100
# 330      48       20    11.976475  10.892145  13.009526         100
# 1114     80       20    11.686761  10.624179  12.676681         100
# 1436     90       20    11.221847  10.457821  12.215291          99
# 1077     79       20     9.863554   8.929931  10.609808         100
#
#            feature  median_gap    lb_gap     ub_gap  count_gap  \
# 274         dihed.    2.269628  1.087330  20.312834        100
# 532          dist.    2.340882  1.156287   5.238080        100
# 1290  logit(dist.)    1.557833  1.122729   6.393267        100
# 951   logit(dist.)    1.698410  1.040743  37.363467        100
# 1252         dist.    1.490528  1.109227  10.612373        100
# ...            ...         ...       ...        ...        ...
# 721         dihed.    1.035172  1.005005   1.112661        100
# 330         dihed.    1.035188  1.004825   1.132446        100
# 1114        dihed.    1.042192  1.006675   1.138558        100
# 1436        dihed.    1.058211  1.003907   1.183888         99
# 1077        dihed.    1.049332  1.006695   1.147855        100
#
#       vamp_rank_per_feature
# 274                     1.0
# 532                     1.0
# 1290                    1.0
# 951                     2.0
# 1252                    2.0
# ...                     ...
# 721                    35.0
# 330                    36.0
# 1114                   37.0
# 1436                   38.0
# 1077                   39.0
#
# [1640 rows x 12 columns]

# %%
vamps.loc[vamps.feature=='dist.', :].sort_values(by='median_gap', ascending=False)
# Out:
#       hp_ix  process  median_vamp    lb_vamp    ub_vamp  count_vamp feature  \
# 1196     12        2     1.955640   1.948739   1.963764         100   dist.
# 1232     16        2     1.959732   1.951614   1.966626         100   dist.
# 1225     57        2     1.954012   1.945903   1.962375         100   dist.
# 1544     88        2     1.927643   1.916612   1.941842         100   dist.
# 1078     59        2     1.943997   1.934144   1.952701         100   dist.
# ...     ...      ...          ...        ...        ...         ...     ...
# 619      42       20    16.649397  15.992891  17.114722         100   dist.
# 1165     27       20    15.505645  14.946321  16.162843         100   dist.
# 1164     27       19    14.853619  14.330597  15.485474         100   dist.
# 892      97       19    15.452758  14.972868  15.958639         100   dist.
# 1163     27       18    14.197417  13.706929  14.805563         100   dist.
#
#       median_gap    lb_gap    ub_gap  count_gap  rank_vamp_per_proc  \
# 1196    5.078195  2.863688  7.795656        100                53.0
# 1232    4.112129  1.536300  6.889376        100                39.0
# 1225    3.950333  1.712783  6.765889        100                58.0
# 1544    3.074728  1.499165  4.796777        100                91.0
# 1078    2.859638  1.265975  4.670444        100                77.0
# ...          ...       ...       ...        ...                 ...
# 619     1.027893  1.004791  1.101074        100                21.0
# 1165    1.027686  1.005087  1.093741        100                44.0
# 1164    1.027619  1.005646  1.118836        100                44.0
# 892     1.025853  1.004489  1.110358        100                25.0
# 1163    1.024699  1.004458  1.097007        100                44.0
#
#       rank_gap_per_feature
# 1196                   1.0
# 1232                   2.0
# 1225                   3.0
# 1544                   4.0
# 1078                   5.0
# ...                    ...
# 619                  318.0
# 1165                 319.0
# 1164                 320.0
# 892                  321.0
# 1163                 322.0
#
# [322 rows x 13 columns]

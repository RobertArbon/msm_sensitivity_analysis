# %%
space = {'cluster__max_iter': 1000, 
         'cluster__stride': 10, 
         'tica__dim': hp.quniform('tica__dim', 1, 20, 1), 
         'tica__lag': hp.quniform('tica__lag', 1, 100, 1), 
         'tica__kinetic_map': True, 
         'tica__stride': 1, 
         'cluster__k': hp.quniform('cluster__k', 10, 500, 1), 
          'feature__value': hp.choice('feature__value', [
           {'feature__value': 'dihedrals', 
           'dihedrals__which': 'all'},
            {'feature__value': 'distances', 
            'distances__scheme': hp.choice('distances__scheme', ['ca', 'closest-heavy']), 
            'distances__transform': hp.choice('distances__transform', [
                                             'linear', 
                                             {'distances__transform': 'logistic', 
                                              'distances__steepness': hp.uniform('distances__steepness', 0.1, 50), 
                                              'distances__centre': hp.uniform('distances__centre', 0.2, 1.5)}])}
            ])
        }

# %%
def flatten(d):
    items = []
    for k, v in d.items():
        if isinstance(v, dict):
            items.extend(flatten(v).items())
        else:
            items.append((k, v))
    return dict(items)

# %%
df = pd.concat([pd.DataFrame.from_dict({k: [v] for k, v in flatten(dict(sample(space))).items()}) for i in range(100)])

# %%
df.head()
# Out:
#    cluster__k  cluster__max_iter  cluster__stride distances__scheme  \
# 0        78.0               1000               10     closest-heavy
# 0       485.0               1000               10                ca
# 0       282.0               1000               10     closest-heavy
# 0       271.0               1000               10     closest-heavy
# 0       442.0               1000               10     closest-heavy
#
#   distances__transform feature__value  tica__dim  tica__kinetic_map  \
# 0               linear      distances        8.0               True
# 0             logistic      distances       10.0               True
# 0               linear      distances       19.0               True
# 0             logistic      distances       19.0               True
# 0             logistic      distances        5.0               True
#
#    tica__lag  tica__stride  distances__centre  distances__steepness  \
# 0       62.0             1                NaN                   NaN
# 0       87.0             1           0.504912             30.987357
# 0       66.0             1                NaN                   NaN
# 0       34.0             1           1.011798             45.680548
# 0       83.0             1           1.293989             27.443870
#
#   dihedrals__which
# 0              NaN
# 0              NaN
# 0              NaN
# 0              NaN
# 0              NaN

# %%
df
# Out:
#     cluster__k  cluster__max_iter  cluster__stride distances__scheme  \
# 0           78               1000               10     closest-heavy
# 0          485               1000               10                ca
# 0          282               1000               10     closest-heavy
# 0          271               1000               10     closest-heavy
# 0          442               1000               10     closest-heavy
# ..         ...                ...              ...               ...
# 0          432               1000               10               NaN
# 0          494               1000               10                ca
# 0          192               1000               10     closest-heavy
# 0          266               1000               10               NaN
# 0          355               1000               10                ca
#
#    distances__transform feature__value  tica__dim  tica__kinetic_map  \
# 0                linear      distances          8               True
# 0              logistic      distances         10               True
# 0                linear      distances         19               True
# 0              logistic      distances         19               True
# 0              logistic      distances          5               True
# ..                  ...            ...        ...                ...
# 0                   NaN      dihedrals         11               True
# 0              logistic      distances         19               True
# 0              logistic      distances         16               True
# 0                   NaN      dihedrals          7               True
# 0                linear      distances         15               True
#
#     tica__lag  tica__stride  distances__centre  distances__steepness  \
# 0          62             1                NaN                   NaN
# 0          87             1           0.504912             30.987357
# 0          66             1                NaN                   NaN
# 0          34             1           1.011798             45.680548
# 0          83             1           1.293989             27.443870
# ..        ...           ...                ...                   ...
# 0          13             1                NaN                   NaN
# 0          18             1           0.354547             31.077007
# 0          13             1           0.676211             15.512507
# 0           4             1                NaN                   NaN
# 0          79             1                NaN                   NaN
#
#    dihedrals__which
# 0               NaN
# 0               NaN
# 0               NaN
# 0               NaN
# 0               NaN
# ..              ...
# 0               all
# 0               NaN
# 0               NaN
# 0               all
# 0               NaN
#
# [100 rows x 13 columns]

# %%
hps = [ pd.DataFrame.from_dict(flatten(dict(sample(space)))) for i in range(10)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_64187/344559817.py in <module>
# ----> 1 hps = [ pd.DataFrame.from_dict(flatten(dict(sample(space)))) for i in range(10)]
#
# /tmp/ipykernel_64187/344559817.py in <listcomp>(.0)
# ----> 1 hps = [ pd.DataFrame.from_dict(flatten(dict(sample(space)))) for i in range(10)]
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1676
#    1677         if orient != "tight":
# -> 1678             return cls(data, index=index, columns=columns, dtype=dtype)
#    1679         else:
#    1680             realdata = data["data"]
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     635         elif isinstance(data, dict):
#     636             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 637             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     638         elif isinstance(data, ma.MaskedArray):
#     639             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     118         # figure out the index, if necessary
#     119         if index is None:
# --> 120             index = _extract_index(arrays)
#     121         else:
#     122             index = ensure_index(index)
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     662
#     663         if not indexes and not raw_lengths:
# --> 664             raise ValueError("If using all scalar values, you must pass an index")
#     665
#     666         elif have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
pd.concat(hps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_64187/675437799.py in <module>
# ----> 1 pd.concat(hps)
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     344     ValueError: Indexes have overlapping values: ['a']
#     345     """
# --> 346     op = _Concatenator(
#     347         objs,
#     348         axis=axis,
#
# ~/miniconda3/envs/msmsense/lib/python3.9/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     434                     "only Series and DataFrame objs are valid"
#     435                 )
# --> 436                 raise TypeError(msg)
#     437
#     438             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'dict'>'; only Series and DataFrame objs are valid
